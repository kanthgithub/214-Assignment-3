# %% [markdown]
# <a href="https://colab.research.google.com/github/kanthgithub/214-Assignment-3/blob/master/Uber_Ride_Data_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import numpy as np  # np -> fast maths & arrays
import pandas as pd # pd -> tables & data manipulation
import matplotlib.pyplot as plt # plt -> basic plotting
import seaborn as sns # dns ->

# %%
ride_durations = np.array([12, 25, 8, 45, 30, 18, 22, 15, 37,])

# %%
np.mean(ride_durations)
# Out:
# np.float64(23.555555555555557)

# %%
base_fares = np.array([150, 200, 120, 300, 250])
base_fares * 1.5
# Out:
# array([225., 300., 180., 450., 375.])
